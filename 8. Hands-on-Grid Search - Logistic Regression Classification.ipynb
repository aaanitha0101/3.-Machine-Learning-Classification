# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("Social_Network_Ads.csv")

# %%
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0            1
# 1    15810944   35            20000          0            1
# 2    15668575   26            43000          0            0
# 3    15603246   27            57000          0            0
# 4    15804002   19            76000          0            1
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1            0
# 396  15706071   51            23000          1            1
# 397  15654296   50            20000          1            0
# 398  15755018   36            33000          0            1
# 399  15594041   49            36000          1            0
#
# [400 rows x 5 columns]

# %%
dataset["Purchased"].value_counts()
# Out:
# 0    257
# 1    143
# Name: Purchased, dtype: int64

# %%
dataset.drop("User ID", axis=1)
# Out:
#      Age  EstimatedSalary  Purchased  Gender_Male
# 0     19            19000          0            1
# 1     35            20000          0            1
# 2     26            43000          0            0
# 3     27            57000          0            0
# 4     19            76000          0            1
# ..   ...              ...        ...          ...
# 395   46            41000          1            0
# 396   51            23000          1            1
# 397   50            20000          1            0
# 398   36            33000          0            1
# 399   49            36000          1            0
#
# [400 rows x 4 columns]

# %%
dataset.columns
# Out:
# Index(['User ID', 'Age', 'EstimatedSalary', 'Purchased', 'Gender_Male'], dtype='object')

# %%
indep=dataset[['Age', 'EstimatedSalary', 'Gender_Male']]

# %%
dep=dataset[['Purchased']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(indep,dep,test_size=0.3,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
param_grid ={
    'C':[0.1,1,10],
    'solver':['liblinear', 'saga', 'lbfgs'],
    'penalty':['l2']
            }
grid=GridSearchCV(LogisticRegression(),param_grid,refit='True',verbose=3,n_jobs=-1,scoring='f1_weighted')
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# C:\Users\AH22634\AppData\Local\Anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=LogisticRegression(), n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10], 'penalty': ['l2'],
#                          'solver': ['liblinear', 'saga', 'lbfgs']},
#              refit='True', scoring='f1_weighted', verbose=3)

# %%
re=grid.cv_results_
print("Best parameter {}:".format(grid.best_params_))
# Out:
# Best parameter {'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}:

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0       0.012608      0.004136         0.000000        0.000000     0.1
# 1       0.003148      0.006296         0.006286        0.007699     0.1
# 2       0.003180      0.006360         0.005454        0.006863     0.1
# 3       0.007834      0.006834         0.001104        0.001434       1
# 4       0.003169      0.006338         0.000000        0.000000       1
# 5       0.013782      0.005366         0.000000        0.000000       1
# 6       0.000000      0.000000         0.006365        0.007796      10
# 7       0.007379      0.006360         0.001139        0.002278      10
# 8       0.009031      0.007409         0.003524        0.006093      10
#
#   param_penalty param_solver  \
# 0            l2    liblinear
# 1            l2         saga
# 2            l2        lbfgs
# 3            l2    liblinear
# 4            l2         saga
# 5            l2        lbfgs
# 6            l2    liblinear
# 7            l2         saga
# 8            l2        lbfgs
#
#                                               params  split0_test_score  \
# 0  {'C': 0.1, 'penalty': 'l2', 'solver': 'libline...           0.819142
# 1      {'C': 0.1, 'penalty': 'l2', 'solver': 'saga'}           0.812540
# 2     {'C': 0.1, 'penalty': 'l2', 'solver': 'lbfgs'}           0.812540
# 3   {'C': 1, 'penalty': 'l2', 'solver': 'liblinear'}           0.835985
# 4        {'C': 1, 'penalty': 'l2', 'solver': 'saga'}           0.835985
# 5       {'C': 1, 'penalty': 'l2', 'solver': 'lbfgs'}           0.835985
# 6  {'C': 10, 'penalty': 'l2', 'solver': 'liblinear'}           0.835985
# 7       {'C': 10, 'penalty': 'l2', 'solver': 'saga'}           0.835985
# 8      {'C': 10, 'penalty': 'l2', 'solver': 'lbfgs'}           0.835985
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.802399           0.644599           0.927778           0.926743
# 1           0.763089           0.644599           0.909115           0.888158
# 2           0.763089           0.644599           0.909115           0.888158
# 3           0.802399           0.644599           0.927778           0.890114
# 4           0.802399           0.644599           0.927778           0.890114
# 5           0.802399           0.644599           0.927778           0.890114
# 6           0.802399           0.644599           0.927778           0.890114
# 7           0.802399           0.644599           0.927778           0.890114
# 8           0.802399           0.644599           0.927778           0.890114
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.824132        0.103924                1
# 1         0.803500        0.095169                8
# 2         0.803500        0.095169                8
# 3         0.820175        0.097839                2
# 4         0.820175        0.097839                2
# 5         0.820175        0.097839                2
# 6         0.820175        0.097839                2
# 7         0.820175        0.097839                2
# 8         0.820175        0.097839                2

# %%
y_pred=grid.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
print (cm)
# Out:
# [[74  5]
#  [10 31]]

# %%
from sklearn.metrics import classification_report
cr=classification_report(y_test,y_pred)
print (cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91        79
#            1       0.86      0.76      0.81        41
#
#     accuracy                           0.88       120
#    macro avg       0.87      0.85      0.86       120
# weighted avg       0.87      0.88      0.87       120

# %%
from sklearn.metrics import roc_auc_score
roc=roc_auc_score(y_test,grid.predict_proba(x_test)[:,1])
print(roc)
# Out:
# 0.9481321395492437

# %%
result=grid.predict([[19,19000,1]])
print(result)
# Out:
# [1]

# %%
#to save the model
import pickle
fn="Logistic Regression Classification.sav"
pickle.dump(grid,open(fn,'wb'))

# %%
#to load the model
lm=pickle.load(open(fn,'rb'))
res=lm.predict([[19,19000,1]])
print(res)
# Out:
# [1]

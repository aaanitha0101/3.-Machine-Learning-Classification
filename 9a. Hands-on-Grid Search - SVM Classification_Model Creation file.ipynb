# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("Social_Network_Ads.csv")

# %%
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset.drop("User ID",axis=1)
# Out:
#      Age  EstimatedSalary  Purchased  Gender_Male
# 0     19            19000          0            1
# 1     35            20000          0            1
# 2     26            43000          0            0
# 3     27            57000          0            0
# 4     19            76000          0            1
# ..   ...              ...        ...          ...
# 395   46            41000          1            0
# 396   51            23000          1            1
# 397   50            20000          1            0
# 398   36            33000          0            1
# 399   49            36000          1            0
#
# [400 rows x 4 columns]

# %%
dataset['Purchased'].value_counts()
# Out:
# 0    257
# 1    143
# Name: Purchased, dtype: int64

# %%
dataset.columns
# Out:
# Index(['User ID', 'Age', 'EstimatedSalary', 'Purchased', 'Gender_Male'], dtype='object')

# %%
indep=dataset[['Age', 'EstimatedSalary', 'Gender_Male']]

# %%
dep=dataset[['Purchased']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(indep,dep,test_size=0.3,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
param_grid={
    "C":[0.1,1,10,100],
    "kernel":['linear', 'poly', 'rbf', 'sigmoid'],
    "gamma":['auto','scale']
}
grid=GridSearchCV(SVC(probability=True),param_grid,refit=True,n_jobs=-1,verbose=3,scoring='f1_weighted')
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# C:\Users\AH22634\AppData\Local\Anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVC(probability=True), n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10, 100], 'gamma': ['auto', 'scale'],
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid']},
#              scoring='f1_weighted', verbose=3)

# %%
re=grid.cv_results_
print("Best parameter {}:".format(grid.best_params_))
# Out:
# Best parameter {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}:

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.015594      0.003207         0.004013        0.002053     0.1
# 1        0.020081      0.005727         0.003156        0.000655     0.1
# 2        0.031694      0.005364         0.004393        0.001525     0.1
# 3        0.033405      0.006492         0.003426        0.000862     0.1
# 4        0.018537      0.005018         0.004403        0.001487     0.1
# 5        0.023084      0.004080         0.004917        0.001005     0.1
# 6        0.036532      0.003324         0.005697        0.001371     0.1
# 7        0.027051      0.003515         0.006570        0.000810     0.1
# 8        0.018181      0.002439         0.003782        0.000318       1
# 9        0.019214      0.002335         0.003552        0.001346       1
# 10       0.022076      0.004633         0.004748        0.001086       1
# 11       0.023703      0.003621         0.005431        0.002347       1
# 12       0.016990      0.002734         0.004370        0.001093       1
# 13       0.019469      0.000997         0.003269        0.001032       1
# 14       0.018832      0.003690         0.003736        0.001245       1
# 15       0.024557      0.003843         0.006408        0.002121       1
# 16       0.022043      0.004420         0.002476        0.001634      10
# 17       0.023632      0.007231         0.003236        0.002257      10
# 18       0.020545      0.003193         0.005825        0.001649      10
# 19       0.023254      0.003178         0.004052        0.002335      10
# 20       0.028519      0.001968         0.005226        0.002050      10
# 21       0.028834      0.007256         0.004023        0.002623      10
# 22       0.026122      0.006253         0.004831        0.001484      10
# 23       0.020317      0.004655         0.002576        0.001792      10
# 24       0.077661      0.007657         0.003729        0.001421     100
# 25       0.074112      0.011259         0.003170        0.000950     100
# 26       0.028292      0.008889         0.003970        0.003365     100
# 27       0.016000      0.003478         0.003274        0.001837     100
# 28       0.069873      0.011405         0.002417        0.000807     100
# 29       0.086555      0.025719         0.002589        0.000862     100
# 30       0.024254      0.003227         0.003623        0.000805     100
# 31       0.017062      0.002208         0.005588        0.003184     100
#
#    param_gamma param_kernel  \
# 0         auto       linear
# 1         auto         poly
# 2         auto          rbf
# 3         auto      sigmoid
# 4        scale       linear
# 5        scale         poly
# 6        scale          rbf
# 7        scale      sigmoid
# 8         auto       linear
# 9         auto         poly
# 10        auto          rbf
# 11        auto      sigmoid
# 12       scale       linear
# 13       scale         poly
# 14       scale          rbf
# 15       scale      sigmoid
# 16        auto       linear
# 17        auto         poly
# 18        auto          rbf
# 19        auto      sigmoid
# 20       scale       linear
# 21       scale         poly
# 22       scale          rbf
# 23       scale      sigmoid
# 24        auto       linear
# 25        auto         poly
# 26        auto          rbf
# 27        auto      sigmoid
# 28       scale       linear
# 29       scale         poly
# 30       scale          rbf
# 31       scale      sigmoid
#
#                                                params  split0_test_score  \
# 0     {'C': 0.1, 'gamma': 'auto', 'kernel': 'linear'}           0.812540
# 1       {'C': 0.1, 'gamma': 'auto', 'kernel': 'poly'}           0.802555
# 2        {'C': 0.1, 'gamma': 'auto', 'kernel': 'rbf'}           0.855314
# 3    {'C': 0.1, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.753521
# 4    {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}           0.812540
# 5      {'C': 0.1, 'gamma': 'scale', 'kernel': 'poly'}           0.755102
# 6       {'C': 0.1, 'gamma': 'scale', 'kernel': 'rbf'}           0.855314
# 7   {'C': 0.1, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.753521
# 8       {'C': 1, 'gamma': 'auto', 'kernel': 'linear'}           0.812540
# 9         {'C': 1, 'gamma': 'auto', 'kernel': 'poly'}           0.791441
# 10         {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'}           0.874254
# 11     {'C': 1, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.750000
# 12     {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}           0.812540
# 13       {'C': 1, 'gamma': 'scale', 'kernel': 'poly'}           0.791441
# 14        {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}           0.874254
# 15    {'C': 1, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.726641
# 16     {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}           0.835985
# 17       {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}           0.833024
# 18        {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}           0.892857
# 19    {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.769053
# 20    {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}           0.835985
# 21      {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}           0.833024
# 22       {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}           0.892857
# 23   {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.769053
# 24    {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.835985
# 25      {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}           0.833024
# 26       {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.855314
# 27   {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.769053
# 28   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.835985
# 29     {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}           0.833024
# 30      {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           0.855314
# 31  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.769053
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.763089           0.644599           0.909115
# 1            0.723577           0.618196           0.870721
# 2            0.857143           0.821429           0.964572
# 3            0.721707           0.644599           0.909115
# 4            0.763089           0.644599           0.909115
# 5            0.747056           0.618196           0.890114
# 6            0.857143           0.821429           0.964572
# 7            0.721707           0.644599           0.909115
# 8            0.782971           0.644599           0.927778
# 9            0.835985           0.658971           0.946153
# 10           0.875644           0.823129           0.947015
# 11           0.715601           0.601841           0.875548
# 12           0.782971           0.644599           0.927778
# 13           0.835985           0.658971           0.946153
# 14           0.875644           0.823129           0.947015
# 15           0.715601           0.601841           0.806465
# 16           0.782971           0.644599           0.927778
# 17           0.799537           0.737557           0.928571
# 18           0.875644           0.841398           0.947015
# 19           0.733523           0.730543           0.753871
# 20           0.782971           0.644599           0.927778
# 21           0.799537           0.737557           0.928571
# 22           0.875644           0.841398           0.947015
# 23           0.733523           0.610390           0.753871
# 24           0.782971           0.644599           0.927778
# 25           0.799537           0.715601           0.928571
# 26           0.892857           0.859435           0.929144
# 27           0.714286           0.750000           0.686036
# 28           0.782971           0.644599           0.927778
# 29           0.799537           0.737557           0.928571
# 30           0.892857           0.859435           0.929144
# 31           0.714286           0.750000           0.753871
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.888158         0.803500        0.095169               21
# 1            0.758537         0.754717        0.084104               25
# 2            0.963889         0.892469        0.059958                7
# 3            0.847662         0.775321        0.093351               23
# 4            0.888158         0.803500        0.095169               21
# 5            0.758537         0.753801        0.086069               26
# 6            0.963889         0.892469        0.059958                7
# 7            0.847662         0.775321        0.093351               23
# 8            0.890114         0.811600        0.098358               19
# 9            0.826525         0.811815        0.092329               17
# 10           0.964286         0.896866        0.051883                3
# 11           0.800053         0.748608        0.090986               29
# 12           0.890114         0.811600        0.098358               19
# 13           0.826525         0.811815        0.092329               17
# 14           0.964286         0.896866        0.051883                3
# 15           0.800053         0.730120        0.074024               31
# 16           0.890114         0.816289        0.098849               13
# 17           0.888158         0.837369        0.066798               10
# 18           0.946153         0.900613        0.041029                1
# 19           0.759910         0.749380        0.014996               28
# 20           0.890114         0.816289        0.098849               13
# 21           0.888158         0.837369        0.066798               10
# 22           0.946153         0.900613        0.041029                1
# 23           0.759910         0.725349        0.058652               32
# 24           0.890114         0.816289        0.098849               13
# 25           0.907658         0.836878        0.076857               12
# 26           0.928571         0.893064        0.031996                5
# 27           0.759910         0.735857        0.031074               30
# 28           0.890114         0.816289        0.098849               13
# 29           0.907658         0.841269        0.070136                9
# 30           0.928571         0.893064        0.031996                5
# 31           0.759910         0.749424        0.018709               27

# %%
y_pred=grid.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
print (cm)
# Out:
# [[73  6]
#  [ 4 37]]

# %%
from sklearn.metrics import classification_report
cr=classification_report(y_test,y_pred)
print (cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.94        79
#            1       0.86      0.90      0.88        41
#
#     accuracy                           0.92       120
#    macro avg       0.90      0.91      0.91       120
# weighted avg       0.92      0.92      0.92       120

# %%
from sklearn.metrics import roc_auc_score
roc=roc_auc_score(y_test,grid.predict_proba(x_test)[:,1])
print (roc)
# Out:
# 0.9654214263661625

# %%
age=int(input("Age:"))
sal=float(input("Salary:"))
gen=int(input("Gender:"))
# Out:
# Age:46
# Salary:41000
# Gender:0

# %%
result=grid.predict([[age,sal,gen]])

# %%
print("Purchased:{}".format(result))
# Out:
# Purchased:[1]

# %%
#to save the model
import pickle
fn="SVM Classification.sav"
pickle.dump(grid,open(fn,'wb'))

# %%
#to load the model
lm=pickle.load(open(fn,'rb'))
res=lm.predict([[46,41000,0]])
print(res)
# Out:
# [1]
